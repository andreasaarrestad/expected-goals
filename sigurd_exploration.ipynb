# %%
import pandas as pd
import xmltodict

# %%
path = "./data/27870286.xml"

parse = {"event": ["type", "stime", "side","mtime", "info", "matchscore", "posx", "posy", "ballspotting"]}
data = pd.read_xml(path, iterparse = parse)
data
# Out:
#       type          stime  side         mtime                   info  \
# 0     1010  1651490108813  none         00:00               Betstart
# 1      164  1651490111813  none         00:00          Weather: GOOD
# 2     1014  1651490112813  none         00:00  Pitch condition: GOOD
# 3     1024  1651490883895  none         00:00   Match about to start
# 4     1012  1651491033914  home         00:00          Kick off [T1]
# ...    ...            ...   ...           ...                    ...
# 1222   110  1651497846769  away  90:00 +03:51   [T2] have possession
# 1223  1030  1651497846769  away  90:00 +03:51         Ball safe [T2]
# 1224  1030  1651497856769  away  90:00 +04:01         Ball safe [T2]
# 1225  1011  1651497860769  none  90:00 +04:05                Betstop
# 1226  1013  1651497860769  none         90:00                  ENDED
#
#      matchscore  posx  posy ballspotting
# 0           0:0   NaN   NaN         None
# 1           0:0   NaN   NaN         None
# 2           0:0   NaN   NaN         None
# 3           0:0   NaN   NaN         None
# 4           0:0   NaN   NaN         None
# ...         ...   ...   ...          ...
# 1222        2:2   NaN   NaN         None
# 1223        2:2  91.0  44.0        false
# 1224        2:2  58.0  78.0         true
# 1225        2:2   NaN   NaN         None
# 1226        2:2   NaN   NaN         None
#
# [1227 rows x 9 columns]
